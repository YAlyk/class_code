# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
mall = pd.read_csv('Mall_Customers.csv')
stores = pd.read_csv('stores.csv')
train = pd.read_csv('train.csv')

# %% [markdown]
# 1)Кто в среднем имеет больший среднегодовой доход в 19 лет – мужчины или женщины?</br>
# 2)Покупателей какого возраста больше остальных в магазине? (одно число, не диапазон

# %%
mall.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
mall.loc[mall['Age'] == 19].groupby('Genre').agg({'Annual Income (k$)':'mean'})
# Out:
#         Annual Income (k$)
# Genre
# Female           64.000000
# Male             54.666667

# %%
a = mall.groupby('Age', as_index=False).agg({'CustomerID':'count'})
a.loc[a['CustomerID'] == a['CustomerID'].max()]
# Out:
#     Age  CustomerID
# 14   32          11

# %%
stores['Size'].hist()
# Out:
# <AxesSubplot: >

# %%
stores.plot.scatter(x='Size', y='Type')
# Out:
# <AxesSubplot: xlabel='Size', ylabel='Type'>

# %% [markdown]
# Откройте файл train.csv</br>
#
# Постройте scatter, показывающий доход каждого магазина. Номер магазина по горизонтальной оси, доход – по вертикальной.</br>
# Определите по визуализации номер магазина с максимальным доходом (разовым). Определите максимальный доход без визуализации. Сравните результаты</br>

# %%
train.plot.scatter(x='stores', y='Weekly_Sales')
# Out:
# <AxesSubplot: xlabel='stores', ylabel='Weekly_Sales'>

# %%
train.loc[train['Weekly_Sales'] == train['Weekly_Sales'].max()]
# Out:
#        stores  Dept        Date  Weekly_Sales  IsHoliday
# 95373      10    72  2010-11-26     693099.36       True

# %%
sns.lmplot(x = 'Store', y='Size', data=stores, hue='Type', fit_reg=False)

# %%
a = sns.lmplot(x = 'Store', y='Size', data=stores, hue='Type', fit_reg=False)
a.set_axis_labels('Номер магазина', 'Площадь магазина')

# %% [markdown]
# Откройте файл train.csv
#
# Проведите визуализацию данных для магазина под номером 1. По горизонтали – номер департамента магазина. По вертикали – еженедельная выручка. Интересуют данные в недели распродаж и в недели без распродаж</br>
# Какой департамент магазина № 1 продал за неделю больше остальных? Это было в неделю распродаж? Подтвердите ваш ответ графиком</br>
# Постройте scatterplot для магазина № 1. По горизонтальной оси – департамент, по вертикальной – среднее значение продаж в недели распродаж и в обычные недели. Какой Dept в среднем зарабатывает больше всех?</br>
# Проведите визуализацию данных для всех магазинов. По горизонтальной оси – номер магазина. По вертикальной – максимальная, минимальная и средняя выручки (отдельно для недель распродаж и обычных недель). </br>
