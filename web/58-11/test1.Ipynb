# %% [markdown]
# Подписываете ФИО
# Иванов Иван

# %% [markdown]
# Потом вставляете код и запускаете его, чтобы построился график.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

fig, ax = plt.subplots()

x = np.arange(0, 10, 0.1)
y = np.sin(x)
z = np.cos(x)

ax.plot(y, color='blue', label='Sine wave')
ax.plot(z, color='black', label='Cosine wave')

leg = ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# После этого сохраняете в формате PDF или HTML и присылаете в общий чат ТГ.
